# %%
import pandas as pd
import statistics as st

# %%
df=pd.read_csv("StudentsPerformance.csv")

# %%
df
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group C            some high school  free/reduced
# 1    female        group B                 high school  free/reduced
# 2    female        group B            some high school  free/reduced
# 3    female        group B                some college      standard
# 4    female        group C                some college  free/reduced
# ..      ...            ...                         ...           ...
# 995    male        group E                some college      standard
# 996    male        group A                some college      standard
# 997    male        group D                some college      standard
# 998    male        group E          associate's degree  free/reduced
# 999    male        group E           bachelor's degree      standard
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
st.mode(df['math score'])
# Out:
# 65

# %% [markdown]
# # Question2

# %%
st.mode(df['parental level of education'])
# Out:
# 'some college'

# %% [markdown]
# # Question1

# %%
femaledf =df[df['gender']=='female']

# %%
femaledf['gender'].value_counts()
# Out:
# female    518
# Name: gender, dtype: int64

# %%
maledf =df[df['gender']=='male']

# %%
maledf['gender'].value_counts()
# Out:
# male    482
# Name: gender, dtype: int64

# %% [markdown]
# # Question 3

# %%
st.mean(maledf['math score'])
# Out:
# 68.82157676348548

# %%
maledf[maledf['math score']==68]
# Out:
#     gender race/ethnicity parental level of education         lunch  \
# 734   male        group A            some high school  free/reduced
# 735   male        group A                 high school      standard
# 736   male        group B            some high school      standard
# 737   male        group C                 high school      standard
# 738   male        group C            some high school  free/reduced
# 739   male        group C                some college  free/reduced
# 740   male        group C          associate's degree  free/reduced
# 741   male        group D           bachelor's degree      standard
# 742   male        group D                some college      standard
# 743   male        group D                 high school      standard
# 744   male        group D           bachelor's degree  free/reduced
# 745   male        group E                some college      standard
# 746   male        group E           bachelor's degree      standard
# ...

# %%
st.mean(femaledf['math score'])
# Out:
# 63.37644787644788

# %%
femaledf[femaledf['math score']==63]
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 232  female        group B                some college      standard
# 233  female        group B            some high school  free/reduced
# 234  female        group C          associate's degree      standard
# 235  female        group C           bachelor's degree      standard
# 236  female        group C                some college      standard
# 237  female        group C            some high school      standard
# 238  female        group C                 high school      standard
# 239  female        group C                some college      standard
# 240  female        group C                some college  free/reduced
# 241  female        group D                some college  free/reduced
# 242  female        group D           bachelor's degree  free/reduced
# 243  female        group D                some college      standard
# 244  female        group E                some college      standard
#
# ...

# %%
st.mean(maledf['reading score'])
# Out:
# 65.54564315352697

# %%
maledf[maledf['reading score']==65]
# Out:
#     gender race/ethnicity parental level of education         lunch  \
# 632   male        group B                some college  free/reduced
# 675   male        group C          associate's degree      standard
# 707   male        group B          associate's degree      standard
# 716   male        group B                some college      standard
# 740   male        group C          associate's degree  free/reduced
# 763   male        group B                 high school      standard
# 789   male        group B                 high school      standard
#
#     test preparation course  math score  reading score  writing score
# 632               completed          59             65             66
# 675                    none          62             65             58
# 707               completed          65             65             63
# 716                    none          66             65             60
# 740                    none          68             65             61
# ...

# %%
st.mean(femaledf['reading score'])
# Out:
# 72.59073359073359

# %%
femaledf[femaledf['reading score']==72]
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 98   female        group C           bachelor's degree  free/reduced
# 123  female        group C                 high school  free/reduced
# 142  female        group C          associate's degree      standard
# 152  female        group E             master's degree  free/reduced
# 178  female        group A           bachelor's degree      standard
# 187  female        group C                 high school      standard
# 194  female        group D            some high school      standard
# 199  female        group B                 high school  free/reduced
# 200  female        group C                some college      standard
# 209  female        group B           bachelor's degree      standard
# 211  female        group C                 high school      standard
# 222  female        group C                some college  free/reduced
# 229  female        group D           bachelor's degree  free/reduced
# ...

# %%
st.mean(maledf['writing score'])
# Out:
# 63.446058091286304

# %%
maledf[maledf['writing score']==63]
# Out:
#     gender race/ethnicity parental level of education         lunch  \
# 692   male        group D                some college      standard
# 707   male        group B          associate's degree      standard
# 719   male        group D                 high school      standard
# 733   male        group D          associate's degree      standard
# 758   male        group D                some college  free/reduced
# 796   male        group E          associate's degree      standard
# 804   male        group C            some high school      standard
# 887   male        group D          associate's degree      standard
#
#     test preparation course  math score  reading score  writing score
# 692               completed          63             55             63
# 707               completed          65             65             63
# 719                    none          66             69             63
# 733               completed          67             54             63
# ...

# %%
st.mean(femaledf['writing score'])
# Out:
# 72.46718146718146

# %%
femaledf[femaledf['writing score']==72]
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 107  female        group B            some high school  free/reduced
# 147  female        group C           bachelor's degree      standard
# 154  female        group B            some high school      standard
# 171  female        group C                some college      standard
# 186  female        group C          associate's degree      standard
# 202  female        group C                 high school      standard
# 212  female        group D            some high school      standard
# 228  female        group D                some college      standard
# 308  female        group C           bachelor's degree  free/reduced
# 340  female        group B            some high school      standard
# 383  female        group B                 high school      standard
# 395  female        group E            some high school  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
nonedf=df[df['test preparation course']=='none']

# %%
st.mean(nonedf['math score'])
# Out:
# 63.78971962616822

# %%
nonedf[nonedf['math score']==63]
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 232  female        group B                some college      standard
# 234  female        group C          associate's degree      standard
# 235  female        group C           bachelor's degree      standard
# 237  female        group C            some high school      standard
# 238  female        group C                 high school      standard
# 239  female        group C                some college      standard
# 242  female        group D           bachelor's degree  free/reduced
# 243  female        group D                some college      standard
# 683    male        group A          associate's degree      standard
# 684    male        group A                 high school      standard
# 685    male        group B           bachelor's degree      standard
# 687    male        group B                 high school  free/reduced
# 689    male        group C                some college  free/reduced
# ...

# %%
completeddf=df[df['test preparation course']=='completed']

# %%
st.mean(completeddf['math score'])
# Out:
# 69.96648044692738

# %%
completeddf[completeddf['math score']== 69]
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 325  female        group B                 high school      standard
# 326  female        group C                some college      standard
# 330  female        group C             master's degree      standard
# 336  female        group D                some college      standard
# 337  female        group D                 high school      standard
# 338  female        group D            some high school  free/reduced
# 753    male        group C                 high school      standard
# 758    male        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# 325               completed          69             76             74
# 326               completed          69             90             88
# 330               completed          69             84             85
# ...

# %%
st.mean(completeddf['reading score'])
# Out:
# 74.17597765363128

# %%
completeddf[completeddf['reading score']== 74]
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 157  female        group D          associate's degree  free/reduced
# 212  female        group D            some high school      standard
# 267  female        group C            some high school      standard
# 286  female        group B           bachelor's degree      standard
# 291  female        group C           bachelor's degree  free/reduced
# 294  female        group E                 high school  free/reduced
# 296  female        group E                some college      standard
# 307  female        group C            some high school      standard
# 729    male        group C                some college  free/reduced
# 741    male        group D           bachelor's degree      standard
# 779    male        group C           bachelor's degree      standard
# 785    male        group E          associate's degree      standard
# 865    male        group E          associate's degree  free/reduced
# ...

# %%
st.mean(completeddf['writing score'])
# Out:
# 74.68435754189944

# %%
completeddf[completeddf['writing score']==74]
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 149  female        group D                 high school      standard
# 198  female        group B            some high school      standard
# 203  female        group C                 high school      standard
# 251  female        group D            some high school      standard
# 258  female        group A          associate's degree      standard
# 325  female        group B                 high school      standard
# 346  female        group D             master's degree      standard
# 711    male        group D                some college      standard
# 741    male        group D           bachelor's degree      standard
# 768    male        group C           bachelor's degree  free/reduced
# 786    male        group A                 high school      standard
# 790    male        group B                some college      standard
# 905    male        group B          associate's degree  free/reduced
#
# ...

# %% [markdown]
# # Question4

# %%
maledf
# Out:
#     gender race/ethnicity parental level of education         lunch  \
# 518   male        group C                 high school  free/reduced
# 519   male        group A                some college  free/reduced
# 520   male        group B                 high school  free/reduced
# 521   male        group E            some high school      standard
# 522   male        group B                some college  free/reduced
# ..     ...            ...                         ...           ...
# 995   male        group E                some college      standard
# 996   male        group A                some college      standard
# 997   male        group D                some college      standard
# 998   male        group E          associate's degree  free/reduced
# 999   male        group E           bachelor's degree      standard
#
#     test preparation course  math score  reading score  writing score
# 518                    none          27             34             36
# ...

# %%
st.variance(maledf['math score'])
# Out:
# 211.88909688494752

# %%
import math
math.sqrt(211.89)
# Out:
# 14.556441872930348

# %%
st.mean(maledf['math score'])
# Out:
# 68.82157676348548

# %% [markdown]
# ## 68% of males scored between 14.56 standard deviation from mean 64 for math

# %%
variance=st.variance(femaledf['math score'])

# %%
math.sqrt(variance)
# Out:
# 16.029928046024438

# %%
st.mean(femaledf['math score'])
# Out:
# 63.37644787644788

# %% [markdown]
# ## 68% of females scored between 16.02 standard deviation from mean 63.37 for math

# %%
variance=st.variance(maledf['reading score'])
math.sqrt(variance)
# Out:
# 14.149593990092226

# %%
st.mean(maledf['reading score'])
# Out:
# 65.54564315352697

# %% [markdown]
#  68% of males scored between 14.14 standard deviation from mean 65.54 for reading

# %%
variance=st.variance(femaledf['reading score'])
math.sqrt(variance)
# Out:
# 14.411017942724353

# %%
st.mean(femaledf['reading score'])
# Out:
# 72.59073359073359

# %% [markdown]
# # 68% of females scored between 14.41 standard deviation from mean 72 for reading

# %%
variance=st.variance(maledf['writing score'])
math.sqrt(variance)
# Out:
# 14.227224751791564

# %%
st.mean(maledf['writing score'])
# Out:
# 63.446058091286304

# %% [markdown]
# # 68% of males scored between 14.22 standard deviation from mean 63 for writing

# %%
variance=st.variance(femaledf['writing score'])
math.sqrt(variance)
# Out:
# 14.84484176575076

# %%
st.mean(femaledf['writing score'])
# Out:
# 72.46718146718146

# %% [markdown]
# # 68% of females scored between 14.84 standard deviation from mean 72.46 for writing

# %% [markdown]
# # Top 25% of students in math score

# %%
q75=df['math score'].quantile(q=0.75)
q75
# Out:
# 77.0

# %%
df[df['math score'].ge(q75)]
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 414  female        group A                 high school  free/reduced
# 415  female        group B             master's degree  free/reduced
# 416  female        group B           bachelor's degree  free/reduced
# 417  female        group B             master's degree      standard
# 418  female        group B                 high school      standard
# ..      ...            ...                         ...           ...
# 995    male        group E                some college      standard
# 996    male        group A                some college      standard
# 997    male        group D                some college      standard
# 998    male        group E          associate's degree  free/reduced
# 999    male        group E           bachelor's degree      standard
#
#     test preparation course  math score  reading score  writing score
# ...
